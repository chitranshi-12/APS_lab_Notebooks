# %% [markdown]
# <a href="https://colab.research.google.com/github/chitranshi-12/APS_lab_Notebooks/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
lecture_graph = {
    "A": {"B": 7, "D": 5},
    "B": {"A": 7, "C": 8, "D": 9, "E": 7},
    "C": {"B": 8, "E": 5},
    "D": {"A": 5, "B": 9, "E": 15, "F": 6},
    "E": {"B": 7, "C": 5, "D": 15, "F": 8, "G": 9},
    "F": {"D": 6, "E": 8, "G": 11},
    "G": {"E": 9, "F": 11}
}

# %%
#run prims algorithm for sample input
mst_lecture, min_weight_lecture = prim_algorithm(lecture_graph)
print("Minimum Spanning Tree for Lecture Graph: ", mst_lecture)
print("Minimum Weight for Lecture Graph: ", min_weight_lecture)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm
def kruskal_algorithm(graph):
  min_tree = {}
  visited = set()
  min_tree[list(graph.keys()[0])] = []
  min_weight = 0

  while len(visited) < len(graph):
       min_edge = float ('inf')
       next_vertex = None
       for vertex in min_tree:
        for adj_vertex in min_tree:
          for adj_vertex,weight in graph [vertex], item():
           if

# %% [markdown]
# # Task
# Define a new graph structure from a lecture slide example, then run Prim's algorithm on it and print the resulting Minimum Spanning Tree and its total weight.

# %% [markdown]
# ## Define New Graph
#
# ### Subtask:
# Define a new graph structure based on the example discussed in the lecture slide. This will be a dictionary representing the weighted graph, similar to the existing `graph` variable.

# %% [markdown]
# **Reasoning**:
# To define the new graph structure as instructed, I will create a code block with a new dictionary variable named `lecture_graph` and populate it with nodes and weighted edges.

# %%
lecture_graph = {
    "A": {"B": 7, "D": 5},
    "B": {"A": 7, "C": 8, "D": 9, "E": 7},
    "C": {"B": 8, "E": 5},
    "D": {"A": 5, "B": 9, "E": 15, "F": 6},
    "E": {"B": 7, "C": 5, "D": 15, "F": 8, "G": 9},
    "F": {"D": 6, "E": 8, "G": 11},
    "G": {"E": 9, "F": 11}
}

# %% [markdown]
# **Reasoning**:
# Now that the `lecture_graph` is defined, the next step is to run the previously defined `prim_algorithm` function on this new graph and then print the resulting Minimum Spanning Tree and its total weight, as per the main task instructions.

# %%
mst_lecture, min_weight_lecture = prim_algorithm(lecture_graph)
print("Minimum Spanning Tree for Lecture Graph: ", mst_lecture)
print("Minimum Weight for Lecture Graph: ", min_weight_lecture)
# Out:
# Minimum Spanning Tree for Lecture Graph:  {'A': [], 'D': [], 'F': [], 'B': [], 'E': [], 'C': [], 'G': []}
# Minimum Weight for Lecture Graph:  44

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Verify the output of Prim's algorithm against the expected results from the lecture slide example.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The output of Prim's algorithm for the defined `lecture_graph` was calculated, yielding a Minimum Spanning Tree with a total weight of 44. However, the explicit verification against an "expected result from the lecture slide example" was not detailed in the provided process, preventing a direct comparison.
#
# ### Data Analysis Key Findings
# *   A new graph structure named `lecture_graph` was successfully defined, mirroring the example from the lecture slide. This graph includes seven nodes (A, B, C, D, E, F, G) and their respective weighted edges.
# *   Prim's algorithm was applied to the `lecture_graph` to find its Minimum Spanning Tree.
# *   The total weight of the calculated Minimum Spanning Tree for the `lecture_graph` is 44.
#
# ### Insights or Next Steps
# *   To fully complete the task's verification, the calculated MST weight of 44 should be explicitly compared against the expected MST weight presented in the lecture slide example.
# *   Consider enhancing the `prim_algorithm` implementation to return the edges of the MST, in addition to the total weight, for a more comprehensive representation of the Minimum Spanning Tree.

# %% [markdown]
# # Task
# Implement Kruskal's algorithm to find the Minimum Spanning Tree of the `lecture_graph` and print the resulting MST and its total weight. Afterwards, summarize the results of Kruskal's algorithm and compare them with the results obtained from Prim's algorithm for the `lecture_graph`.

# %% [markdown]
# ## Implement Kruskal's Algorithm
#
# ### Subtask:
# Complete the `kruskal_algorithm` function to find the Minimum Spanning Tree of a graph using Kruskal's algorithm. This will involve sorting all edges by weight and using a Union-Find data structure to detect cycles.

# %% [markdown]
# **Reasoning**:
# The first instruction is to define a helper class or functions for a Union-Find data structure. I will create a `UnionFind` class with `__init__`, `find`, and `union` methods to handle set operations and cycle detection for Kruskal's algorithm.

# %%
class UnionFind:
    def __init__(self, vertices):
        self.parent = {v: v for v in vertices}
        self.rank = {v: 0 for v in vertices}

    def find(self, i):
        if self.parent[i] == i:
            return i
        self.parent[i] = self.find(self.parent[i])
        return self.parent[i]

    def union(self, i, j):
        root_i = self.find(i)
        root_j = self.find(j)

        if root_i != root_j:
            if self.rank[root_i] < self.rank[root_j]:
                self.parent[root_i] = root_j
            elif self.rank[root_i] > self.rank[root_j]:
                self.parent[root_j] = root_i
            else:
                self.parent[root_j] = root_i
                self.rank[root_i] += 1
            return True
        return False
